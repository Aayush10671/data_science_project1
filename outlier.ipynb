# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns' , None);

# %%
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat                pyramid elite   sector 86   0.46
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
#
#    price_per_sqft     area                                       areaWithType  \
# 0          7585.0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0   1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 2            79.0  58228.0                 Carpet area: 58141 (5401.48 sq.m.)
# 3          5470.0    585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0   1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# ...

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
sns.distplot(df['price']);
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_2732\2013158146.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price']);

# %%
sns.boxplot(x = df['price']);

# %%
Q1 = df['price'].quantile(0.25);
Q3 = df['price'].quantile(0.75);
IQR = Q3 - Q1;

lower_bound = Q1 - 1.5*IQR;
upper_bound = Q3 + 1.5*IQR

outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)];

num_outliers = outliers.shape[0];
outlier_price_sets = outliers['price'].describe()

num_outliers,
outlier_price_sets
# Out:
# count    425.000000
# mean       9.235624
# std        4.065259
# min        5.460000
# 25%        6.460000
# 50%        8.000000
# 75%       10.750000
# max       31.500000
# Name: price, dtype: float64

# %%
outliers.sort_values('price' , ascending=False).head(20)
# Out:
#      property_type                                            society  \
# 821          house  arjun marg/ sector- 26 phase- 1/ golf course road
# 2834         house                                        independent
# 2488         house                                     dlf city plots
# 2211         house                                        independent
# 1686         house                                   suncity township
# 3046         house                             emaar the palm springs
# 2765         house                                        independent
# 2667         house                                 vipul tatvam villa
# 874          house                                     dlf city plots
# 2096         house                             luxury dlf city floors
# 711          house                                        independent
# 1687         house                                        independent
# ...

# %%
sns.distplot(x = df['price_per_sqft']);
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_2732\4294202317.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = df['price_per_sqft']);

# %%
sns.boxplot( x = df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
Q1 = df['price_per_sqft'].quantile(0.25);
Q3 = df['price_per_sqft'].quantile(0.75);
IQR = Q3 - Q1;

lower_bound = Q1 - 1.5*IQR;
upper_bound = Q3 + 1.5*IQR

outliers = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)];

num_outliers = outliers.shape[0];
outlier_price_sets = outliers['price_per_sqft'].describe()

num_outliers,
outlier_price_sets
# Out:
# count       354.000000
# mean      52592.612994
# std       61150.458507
# min       24489.000000
# 25%       28208.250000
# 50%       33368.500000
# 75%       41982.250000
# max      600000.000000
# Name: price_per_sqft, dtype: float64

# %%
outliers['area'] = outliers['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_2732\1621373245.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers['area'] = outliers['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers['price_per_sqft'] = round(outliers['price']*10000000/outliers['area']);
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_2732\1751561805.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers['price_per_sqft'] = round(outliers['price']*10000000/outliers['area']);

# %%
outliers['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29357.906780
# std      12403.077309
# min       2723.000000
# 25%      25562.000000
# 50%      29870.500000
# 75%      35549.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers);

# %%
df[df['price_per_sqft'] >5000]
# Out:
#      property_type                              society      sector  price  \
# 0             flat              signature global park 4   sector 36   0.82
# 1             flat                     smart world gems   sector 89   0.95
# 3             flat               breez global hill view  sohna road   0.32
# 4             flat          bestech park view sanskruti   sector 92   1.60
# 5             flat                       suncity avenue  sector 102   0.48
# ...            ...                                  ...         ...    ...
# 3798          flat                       pivotal devaan   sector 84   0.37
# 3799         house  international city by sobha phase 1  sector 109   6.00
# 3800          flat           ansal api celebrity suites    sector 2   0.60
# 3801         house                          independent   sector 43  15.50
# 3802          flat                           m3m ikonic   sector 68   1.78
#
#       price_per_sqft    area  \
# 0             7585.0  1081.0
# ...

# %%
sns.distplot(x = df['area']);
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_2732\2474074240.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = df['area']);

# %%
sns.boxplot(x = df['area']);

# %%
df['area'].describe()
# Out:
# count      3660.00000
# mean       2945.99235
# std       23167.02147
# min         145.00000
# 25%        1262.00000
# 50%        1750.00000
# 75%        2350.00000
# max      875000.00000
# Name: area, dtype: float64

# %%
df = df[df['area'] < 100000];

# %%
sns.distplot(x = df['area']);
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_2732\2474074240.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = df['area']);

# %%
df[df['area']>10000]
# Out:
#      property_type                    society      sector  price  \
# 2             flat              pyramid elite   sector 86   0.46
# 48           house  ganpati heights apartment   sector 13   1.25
# 115           flat      signature the serenas  sohna road   0.28
# 300          house      dlf city plot phase 4   sector 28  13.00
# 747          house                independent  sohna road   5.50
# 818          house                independent   sector 26  18.40
# 1123          flat                 rof ananda   sector 95   0.38
# 1358         house                independent   sector 57   6.25
# 1471         house                independent    sector 4   0.85
# 1796          flat                 rof ananda   sector 95   0.38
# 2131          flat                 godrej air   sector 85   2.50
# 2342          flat             m3m golfestate   sector 65  13.20
# 2356          flat                 rof ananda   sector 95   0.33
# ...

# %%
df.drop(index = [818 , 1796 , 1123 , 2 , 2356 , 115 , 3649 , 2503 , 1471] , inplace = True);

# %%
df.loc[48 , 'area'] = 115*9
df.loc[300 , 'area'] = 7250;
df.loc[2666 , 'area'] = 5800
df.loc[1358 , 'area'] = 2660
df.loc[3195 , 'area'] = 2850
df.loc[2131 , 'area'] = 1812
df.loc[3088 , 'area'] = 2160
df.loc[3444 , 'area'] = 1175

# %%
sns.distplot(df['area']);
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_2732\1352360941.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area']);

# %%
sns.boxplot(x = df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count     3646.000000
# mean      1952.175261
# std       1215.333736
# min        145.000000
# 25%       1261.000000
# 50%       1750.000000
# 75%       2336.750000
# max      11286.000000
# Name: area, dtype: float64

# %%
df.bedRoom.describe()
# Out:
# count    3646.000000
# mean        3.351070
# std         1.880711
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('price' , ascending=False).head(20)
# Out:
#      property_type                      society     sector  price  \
# 2211         house                  independent  sector 26  26.00
# 874          house               dlf city plots  sector 26  20.00
# 2096         house       luxury dlf city floors  sector 26  20.00
# 1261         house                  independent  sector 25  16.00
# 1200         house                  independent  sector 26  14.75
# 2039         house                  independent  sector 43  13.50
# 2758         house    floor wise designer kothi  sector 25  13.00
# 3285         house                          nul  sector 28  12.50
# 3457         house                  independent  sector 56  12.39
# 2137         house                  independent  sector 40  12.00
# 2533         house                  independent  sector 56  11.95
# 2686         house                  independent  sector 56  11.50
# 690          house                  independent  sector 28  11.00
# ...

# %%
df = df[df['bedRoom'] <=10]

# %%
sns.displot(x = df['bathroom'])

# %%
df.shape
# Out:
# (3596, 23)

# %%
df.loc[2131 , 'carpet_area'] = 1812

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.02);

# %%
sns.lmplot(data = df , x = 'area' , y = 'bedRoom')

# %%
df['area_room_ratio'] = df['area']/df['bedRoom']

# %%
outliers_df = df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 3)]

# %%
outliers_df['bedRoom'] = round(outliers_df['bedRoom'] / outliers_df['floorNum'])
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_2732\1649205732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_df['bedRoom'] = round(outliers_df['bedRoom'] / outliers_df['floorNum'])

# %%
outliers_df
# Out:
#      property_type                                 society      sector  price  \
# 9            house                             independent  sector 105   1.20
# 15           house                             independent   sector 12   1.20
# 37           house                             independent  sector 104   0.45
# 48           house               ganpati heights apartment   sector 13   1.25
# 74           house                             independent   sector 25   7.60
# ...            ...                                     ...         ...    ...
# 3686         house                             independent   sector 12   0.90
# 3713         house                             independent   sector 41   4.25
# 3738         house                             independent    sector 7   1.16
# 3774         house                             independent   sector 28   0.45
# 3797         house  surendra homes dayaindependentd colony    sector 6   0.75
#
#       price_per_sqft    area  \
# ...

# %%
df.update(outliers_df);

# %%
df = df[~((df['area_room_ratio'] < 250) & (df['bedRoom'] <4 ))]

# %%
sns.lmplot( data = df , x = 'area' , y = 'bedRoom')

# %%
df.to_csv('gurgaon_properties_outliers_treated' , index = False);
