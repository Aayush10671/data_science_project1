# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('flats_cleaned.csv');
houses = pd.read_csv('house_cleaned.csv');

# %%
df = pd.concat([flats,houses],ignore_index = True);

# %%
df = df.sample(df.shape[0] , ignore_index = True);

# %%
df.sample(5)
# Out:
#                         property_name prooerty_type  \
# 2122  4 BHK Flat in Sector 68 Gurgaon          flat
# 3567  4 BHK Flat in Sector 41 Gurgaon          flat
# 3083  2 BHK Flat in Sector 93 Gurgaon          flat
# 1997  3 BHK Flat in Sector 61 Gurgaon          flat
# 1664  4 BHK Flat in Sector 65 Gurgaon          flat
#
#                                society  price  price_per_sqft    area  \
# 2122                   pareena mi casa    1.7          8500.0  2000.0
# 3567               south city 1 floors    3.4         11724.0  2900.0
# 3083   signature global orchard avenue    0.4          7359.0   544.0
# 1997               smart world orchard    2.1         13750.0  1527.0
# 1664  emaar mgf emerald floors premier    3.0         15189.0  1975.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 2122             Super Built up area 1999(185.71 sq.m.)        4         4
# 3567                 Built Up area: 2900 (269.42 sq.m.)        4         4
# 3083                   Carpet area: 543.53 (50.5 sq.m.)        2         2
# 1997  Super Built up area 1549(143.91 sq.m.)Carpet a...        3         2
# 1664             Super Built up area 1975(183.48 sq.m.)        4         4
#
#      balcony  ...                                            address floorNum  \
# 2122      3+  ...          2304, Sector 68 Gurgaon, Gurgaon, Haryana     23.0
# 3567       3  ...  South City 1 Floors, South City I, Sector 41, ...      0.0
# 3083       2  ...                Sector 93 Gurgaon, Gurgaon, Haryana     11.0
# 1997       3  ...         E11-C, Sector 61 Gurgaon, Gurgaon, Haryana      3.0
# 1664      3+  ...  1975 Sq Ft Apartment, Sector 65 Gurgaon, Gurga...      2.0
#
#           facing    agePossession  \
# 2122         NaN  0 to 1 Year Old
# 3567         NaN        undefined
# 3083         NaN  0 to 1 Year Old
# 1997       South         Nov 2023
# 1664  South-East  1 to 5 Year Old
#
#                                         nearbyLocations  \
# 2122  ['Sector 55-56 Metro Station', 'Airia Mall', '...
# 3567  ['Huda city centre metro station', 'Hdfc ATM',...
# 3083  ['JMS Crosswalk Mall', 'Reliance Trends Newtow...
# 1997  ['Sector 55-56 Metro station', 'Bestech Centra...
# 1664  ['WorldMark Gurgaon', 'Sohna Road', 'Golf Cour...
#
#                                             description  \
# 2122  The property is on the 23rd floor with an road...
# 3567  Property for sale in sector 41, gurgaon. This ...
# 3083  Situated in sector-93 gurgaon, gurgaon, signat...
# 1997  Located in the popular residential address of ...
# 1664  Emaar mgf emerald floors premier is one of the...
#
#                                          furnishDetails  \
# 2122  ['1 Modular Kitchen', 'No AC', 'No Bed', 'No C...
# 3567  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 3083  ['1 Fan', '1 Exhaust Fan', '1 Geyser', '5 Ligh...
# 1997                                                NaN
# 1664                                                NaN
#
#                                                features  \
# 2122  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 3567                                                NaN
# 3083  ['Security / Fire Alarm', 'Lift(s)', 'Maintena...
# 1997  ['Centrally Air Conditioned', 'Security / Fire...
# 1664  ['Power Back-up', 'Feng Shui / Vaastu Complian...
#
#                                                  rating property_type
# 2122  ['Safety5 out of 5', 'Lifestyle4 out of 5', 'E...           NaN
# 3567  ['Environment5 out of 5', 'Safety5 out of 5', ...           NaN
# 3083  ['Green Area4 out of 5', 'Construction4 out of...           NaN
# 1997                                                NaN           NaN
# 1664  ['Green Area4.5 out of 5', 'Construction5 out ...           NaN
#
# [5 rows x 21 columns]

# %%
df.to_csv('gurgaon_properties.csv' , index = False);
